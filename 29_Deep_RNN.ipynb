# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense , CuDNNLSTM, LSTM

# %%
(x_train, y_train), (x_test, y_test)= imdb.load_data(num_words= 10000)

x_train= pad_sequences(x_train, maxlen= 100)
x_test= pad_sequences(x_test, maxlen= 100)

# %%
model=  Sequential([
    Embedding(10000, 32, input_length= 100),
    SimpleRNN(5, return_sequences= True), # RNN layer with 5 units
    SimpleRNN(5),
    Dense(1, activation= 'sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 32)           320000
#
#  simple_rnn (SimpleRNN)      (None, 100, 5)            190
#
#  simple_rnn_1 (SimpleRNN)    (None, 5)                 55
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 320,251
# Trainable params: 320,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])

# %%
history= model.fit(x_train , y_train, epochs= 5, batch_size= 32, validation_data= (x_test, y_test))
# Out:
# Epoch 1/5
# 782/782 [==============================] - 130s 162ms/step - loss: 0.6813 - accuracy: 0.5487 - val_loss: 0.6536 - val_accuracy: 0.6038
# Epoch 2/5
# 782/782 [==============================] - 126s 161ms/step - loss: 0.4561 - accuracy: 0.7983 - val_loss: 0.4651 - val_accuracy: 0.7945
# Epoch 3/5
# 782/782 [==============================] - 127s 162ms/step - loss: 0.2779 - accuracy: 0.8914 - val_loss: 0.4962 - val_accuracy: 0.7885
# Epoch 4/5
# 782/782 [==============================] - 126s 161ms/step - loss: 0.1953 - accuracy: 0.9307 - val_loss: 0.5443 - val_accuracy: 0.7921
# Epoch 5/5
# 782/782 [==============================] - 125s 160ms/step - loss: 0.1358 - accuracy: 0.9555 - val_loss: 0.6161 - val_accuracy: 0.7863
