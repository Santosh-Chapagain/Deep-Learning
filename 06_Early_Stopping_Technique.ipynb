# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf 
from tensorflow import keras 
from keras.layers import Dense
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.datasets import make_circles
import seaborn as sns

# %%
x , y = make_circles(n_samples= 100 , noise= 0.1 , random_state= 1)

# %%
sns.scatterplot(x=x[: , 0] , y=x[: , 1] , hue=y)
# Out:
# <Axes: >

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size= 0.2 , random_state= 2)

# %%
model = Sequential()

model.add(Dense(256 , input_dim = 2 , activation= 'relu'))
model.add(Dense(256 , activation= 'relu'))
model.add(Dense(1 , activation= 'sigmoid'))
# Out:
# c:\Users\Acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss= 'binary_crossentropy' , optimizer= 'adam' , metrics= ['accuracy'])

# %%
history = model.fit(x_train , y_train , validation_data= (x_test , y_test) , epochs= 3500 , verbose= 0)

# %%
plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'test')
plt.legend()
plt.show()

# %% [markdown]
# # Early Stopping

# %%
model = Sequential()

model.add(Dense(256 , input_dim = 2 , activation= 'relu'))
model.add(Dense(256 , activation= 'relu'))
model.add(Dense(1  , activation= 'sigmoid'))

# %%
model.compile(loss= 'binary_crossentropy' , optimizer= 'adam' , metrics= ['accuracy'])

# %%
from keras.callbacks import EarlyStopping
callback = EarlyStopping(
    monitor = "val_loss",
    min_delta = 0.0001,
    patience= 50,
    verbose= 1,
    mode = "auto",
    baseline = None,
    restore_best_weights = False,
)

# %%
history = model.fit(x_train , y_train , validation_data= (x_test , y_test) , epochs= 3500 , callbacks= callback)
# Out:
# Epoch 1/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6750 - loss: 0.6448 - val_accuracy: 0.6500 - val_loss: 0.7083
# Epoch 2/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6875 - loss: 0.6409 - val_accuracy: 0.5500 - val_loss: 0.7018
# Epoch 3/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6375 - loss: 0.6386 - val_accuracy: 0.5000 - val_loss: 0.6987
# Epoch 4/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6375 - loss: 0.6347 - val_accuracy: 0.5000 - val_loss: 0.6964
# Epoch 5/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6750 - loss: 0.6313 - val_accuracy: 0.6000 - val_loss: 0.6967
# Epoch 6/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6625 - loss: 0.6258 - val_accuracy: 0.5500 - val_loss: 0.6997
# Epoch 7/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6750 - loss: 0.6203 - val_accuracy: 0.5000 - val_loss: 0.7023
# Epoch 8/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7000 - loss: 0.6147 - val_accuracy: 0.5500 - val_loss: 0.6982
# Epoch 9/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6875 - loss: 0.6088 - val_accuracy: 0.6500 - val_loss: 0.6968
# Epoch 10/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7625 - loss: 0.6023 - val_accuracy: 0.6500 - val_loss: 0.7031
# Epoch 11/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7500 - loss: 0.5927 - val_accuracy: 0.6000 - val_loss: 0.7024
# Epoch 12/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7375 - loss: 0.5902 - val_accuracy: 0.6000 - val_loss: 0.7024
# Epoch 13/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7500 - loss: 0.5816 - val_accuracy: 0.6500 - val_loss: 0.6914
# Epoch 14/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7750 - loss: 0.5700 - val_accuracy: 0.6500 - val_loss: 0.6802
# Epoch 15/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8000 - loss: 0.5617 - val_accuracy: 0.6500 - val_loss: 0.6735
# Epoch 16/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8250 - loss: 0.5521 - val_accuracy: 0.6500 - val_loss: 0.6709
# Epoch 17/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8375 - loss: 0.5435 - val_accuracy: 0.6500 - val_loss: 0.6706
# Epoch 18/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8125 - loss: 0.5330 - val_accuracy: 0.6500 - val_loss: 0.6629
# Epoch 19/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8125 - loss: 0.5233 - val_accuracy: 0.6000 - val_loss: 0.6588
# Epoch 20/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.